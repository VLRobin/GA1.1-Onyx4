# %%
def subtract(a,b):
    answer = a - b
    return answer

subtract(8,4)
# Out:
# 4

# %%
def distance_from_zero(x):
    if x < 0:
        return -x
    else:
        return x

distance_from_zero(subtract(8,4))
# Out:
# 4

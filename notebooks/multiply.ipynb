# %%
def multiply(a, b): 
    return a * b

print(multiply(4, 5))
print(multiply(6, 8))
print(multiply(3, 7))

# %%
def square(a):
    return multiply(a, a)

# %%
print(square(4))
print(square(7))
print(square(37))
